# %%
# !nvidia-smi
# Out:
# Thu Apr 20 05:39:16 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   67C    P8    11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Install TensorFlow and TensorFlow Model Garden

# %%
import tensorflow as tf
print(tf.version.VERSION)
# Out:
# 2.12.0

# %%
#!pip install -q tensorflow==2.3.0

# %%
# !git clone --depth 1 -b v2.3.0 https://github.com/tensorflow/models.git
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 2650, done.
# remote: Counting objects: 100% (2650/2650), done.
# remote: Compressing objects: 100% (2311/2311), done.
# remote: Total 2650 (delta 505), reused 1389 (delta 306), pack-reused 0
# Receiving objects: 100% (2650/2650), 34.02 MiB | 17.94 MiB/s, done.
# Resolving deltas: 100% (505/505), done.
# Note: switching to '400d68abbccda2f0f6609e3a924467718b144233'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false

# %%
# install requirements to use tensorflow/models repository
# !pip install -Uqr models/official/requirements.txt
# you may have to restart the runtime afterwards
# Out:
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 95.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 218.4/218.4 kB 1.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 84.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 107.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.6/240.6 kB 26.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 77.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 591.0/591.0 kB 36.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 66.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 107.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 105.7 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.12.0 requires numpy<1.24,>=1.22, but you have numpy 1.24.2 which is incompatible.
# numba 0.56.4 requires numpy<1.24,>=1.18, but you have numpy 1.24.2 which is incompatible.
# google-colab 1.0.0 requires pandas~=1.5.3, but you have pandas 2.0.0 which is incompatible.

# %%
# !pip install tensorflow-text
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow-text
#   Downloading tensorflow_text-2.12.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 82.8 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow<2.13,>=2.12.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow-text) (2.12.0)
# Requirement already satisfied: tensorflow-hub>=0.8.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow-text) (0.13.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (1.16.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (3.8.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (2.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (16.0.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.9/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (1.53.0)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (2.12.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.9/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (0.4.8)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (1.6.3)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.9/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (3.3.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.9/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (2.12.2)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (0.32.0)
# Collecting numpy<1.24,>=1.22
#   Downloading numpy-1.23.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 78.7 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (67.6.1)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (0.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.9/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (3.20.3)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (1.4.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (23.3.3)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.9/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (4.5.0)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (2.12.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.9/dist-packages (from astunparse>=1.6.0->tensorflow<2.13,>=2.12.0->tensorflow-text) (0.40.0)
# Requirement already satisfied: ml-dtypes>=0.0.3 in /usr/local/lib/python3.9/dist-packages (from jax>=0.3.15->tensorflow<2.13,>=2.12.0->tensorflow-text) (0.1.0)
# Requirement already satisfied: scipy>=1.7 in /usr/local/lib/python3.9/dist-packages (from jax>=0.3.15->tensorflow<2.13,>=2.12.0->tensorflow-text) (1.10.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow-text) (2.27.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow-text) (2.17.3)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow-text) (2.2.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow-text) (0.7.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow-text) (1.0.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow-text) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow-text) (3.4.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow-text) (5.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow-text) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow-text) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow-text) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.9/dist-packages (from markdown>=2.6.8->tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow-text) (6.4.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow-text) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow-text) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow-text) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow-text) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.9/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow-text) (2.1.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow-text) (3.15.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow-text) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow-text) (3.2.2)
# Installing collected packages: numpy, tensorflow-text
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.2
#     Uninstalling numpy-1.24.2:
#       Successfully uninstalled numpy-1.24.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas~=1.5.3, but you have pandas 2.0.0 which is incompatible.
# Successfully installed numpy-1.23.5 tensorflow-text-2.12.1

# %%
import numpy as np
import tensorflow as tf
import tensorflow_hub as hub
import sys
sys.path.append('models')
from official.nlp.data import classifier_data_lib
from official.nlp.bert import tokenization
from official.nlp import optimization
import tensorflow_text as text
import pandas as pd 
from tensorflow import keras
from tensorflow.keras.layers import Dense, Dropout, Bidirectional, LSTM
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, LSTM, SpatialDropout1D
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Embedding, LSTM, Dense ## Neural networks layers 
from tensorflow.keras import layers
from keras import regularizers
import re
import warnings; warnings.simplefilter('ignore')
import tqdm
# Out:
# /usr/local/lib/python3.9/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
print("TF Version: ", tf.__version__)
print("Eager mode: ", tf.executing_eagerly())
print("Hub version: ", hub.__version__)
print("GPU is", "available" if tf.config.experimental.list_physical_devices("GPU") else "NOT AVAILABLE")
# Out:
# TF Version:  2.12.0
# Eager mode:  True
# Hub version:  0.13.0
# GPU is available

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('always')

# %%
df_train = pd.read_csv('/content/drive/MyDrive/Propaganda/propaganda_dataset_v2/propaganda_dataset_v2/propaganda_train.tsv',sep='\t')
df_train
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                       label                                  tagged_in_context
# 0            not_propaganda         No, <BOS> he <EOS> will not be confirmed.
# 1            not_propaganda  This declassification effort <BOS> won’t make ...
# 2               flag_waving  The Obama administration misled the <BOS> Amer...
# 3            not_propaganda  “It looks like we’re capturing the demise of t...
# 4            not_propaganda           <BOS> Location: Westerville, Ohio <EOS>
# ...                     ...                                                ...
# 2409         not_propaganda  <BOS> We support and appreciate <EOS> your bus...
# 2410         not_propaganda  International Atomic Energy Agency (IAEA) Dire...
# 2411         not_propaganda  What has been done: there has been work on for...
# 2412         not_propaganda  This is <BOS> the law of gradualness not the g...
# 2413  name_calling,labeling  In it, Jews are described as: “arrogant,” “jea...
#
# [2414 rows x 2 columns]

# %%
df_train['label'].unique()
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# array(['not_propaganda', 'flag_waving', 'loaded_language', 'doubt',
#        'name_calling,labeling', 'appeal_to_fear_prejudice', 'repetition',
#        'causal_oversimplification', 'exaggeration,minimisation'],
#       dtype=object)

# %%
def get_label_data(tagged_in_context):
     label_data=[]
     for i in tagged_in_context:
          m=re.search('<BOS>(.+?)<EOS>', i)
          found = m.group(1)
          label_data.append(found)
     return label_data
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
label_data_train=get_label_data(df_train.tagged_in_context)
df_train['label_data']=label_data_train
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df_train
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                       label
# 0            not_propaganda  \
# 1            not_propaganda
# 2               flag_waving
# 3            not_propaganda
# 4            not_propaganda
# ...                     ...
# 2409         not_propaganda
# 2410         not_propaganda
# 2411         not_propaganda
# 2412         not_propaganda
# 2413  name_calling,labeling
#
#                                       tagged_in_context
# 0            No, <BOS> he <EOS> will not be confirmed.   \
# 1     This declassification effort <BOS> won’t make ...
# 2     The Obama administration misled the <BOS> Amer...
# 3     “It looks like we’re capturing the demise of t...
# 4              <BOS> Location: Westerville, Ohio <EOS>
# ...                                                 ...
# 2409  <BOS> We support and appreciate <EOS> your bus...
# 2410  International Atomic Energy Agency (IAEA) Dire...
# 2411  What has been done: there has been work on for...
# 2412  This is <BOS> the law of gradualness not the g...
# 2413  In it, Jews are described as: “arrogant,” “jea...
#
#                                              label_data
# 0                                                   he
# 1      won’t make things any worse than they are for...
# 2                                      American people
# 3                                                  and
# 4                          Location: Westerville, Ohio
# ...                                                 ...
# 2409                         We support and appreciate
# 2410   capacity to check whether Iran was conducting...
# 2411                            one for those recently
# 2412   the law of gradualness not the gradualness of...
# 2413                                           selfish
#
# [2414 rows x 3 columns]

# %%
df_train['multi_label'] = pd.Categorical(df_train['label']).codes
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df_train
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                       label
# 0            not_propaganda  \
# 1            not_propaganda
# 2               flag_waving
# 3            not_propaganda
# 4            not_propaganda
# ...                     ...
# 2409         not_propaganda
# 2410         not_propaganda
# 2411         not_propaganda
# 2412         not_propaganda
# 2413  name_calling,labeling
#
#                                       tagged_in_context
# 0            No, <BOS> he <EOS> will not be confirmed.   \
# 1     This declassification effort <BOS> won’t make ...
# 2     The Obama administration misled the <BOS> Amer...
# 3     “It looks like we’re capturing the demise of t...
# 4              <BOS> Location: Westerville, Ohio <EOS>
# ...                                                 ...
# 2409  <BOS> We support and appreciate <EOS> your bus...
# 2410  International Atomic Energy Agency (IAEA) Dire...
# 2411  What has been done: there has been work on for...
# 2412  This is <BOS> the law of gradualness not the g...
# 2413  In it, Jews are described as: “arrogant,” “jea...
#
#                                              label_data  multi_label
# 0                                                   he             7
# 1      won’t make things any worse than they are for...            7
# 2                                      American people             4
# 3                                                  and             7
# 4                          Location: Westerville, Ohio             7
# ...                                                 ...          ...
# 2409                         We support and appreciate             7
# 2410   capacity to check whether Iran was conducting...            7
# 2411                            one for those recently             7
# 2412   the law of gradualness not the gradualness of...            7
# 2413                                           selfish             6
#
# [2414 rows x 4 columns]

# %%
df_test=pd.read_csv('/content/drive/MyDrive/Propaganda/propaganda_dataset_v2/propaganda_dataset_v2/propaganda_val.tsv',sep='\t')
df_test
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                          label
# 0               not_propaganda  \
# 1    causal_oversimplification
# 2     appeal_to_fear_prejudice
# 3               not_propaganda
# 4                   repetition
# ..                         ...
# 575             not_propaganda
# 576             not_propaganda
# 577             not_propaganda
# 578                flag_waving
# 579  causal_oversimplification
#
#                                      tagged_in_context
# 0    On average, between 300 and 600 infections are...
# 1    Mostly because <BOS> the country would not las...
# 2    Lyndon Johnson <BOS> gets Earl Warren and Sen....
# 3             <BOS> You <EOS> may opt out at anytime.
# 4    It must be exacted from him directly in order ...
# ..                                                 ...
# 575  NewsCatholic Church, <BOS> Family, Marriage <E...
# 576  Remember our saying, modern day fairy <BOS> ta...
# 577  Why <BOS> not <EOS> open up to Iran with massi...
# 578  <BOS> He also sang an Islamic State fight song...
# 579  We hear again, as we did incessantly from the ...
#
# [580 rows x 2 columns]

# %%
label_data_test=get_label_data(df_test.tagged_in_context)
df_test['label_data']=label_data_test
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df_test
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                          label
# 0               not_propaganda  \
# 1    causal_oversimplification
# 2     appeal_to_fear_prejudice
# 3               not_propaganda
# 4                   repetition
# ..                         ...
# 575             not_propaganda
# 576             not_propaganda
# 577             not_propaganda
# 578                flag_waving
# 579  causal_oversimplification
#
#                                      tagged_in_context
# 0    On average, between 300 and 600 infections are...  \
# 1    Mostly because <BOS> the country would not las...
# 2    Lyndon Johnson <BOS> gets Earl Warren and Sen....
# 3             <BOS> You <EOS> may opt out at anytime.
# 4    It must be exacted from him directly in order ...
# ..                                                 ...
# 575  NewsCatholic Church, <BOS> Family, Marriage <E...
# 576  Remember our saying, modern day fairy <BOS> ta...
# 577  Why <BOS> not <EOS> open up to Iran with massi...
# 578  <BOS> He also sang an Islamic State fight song...
# 579  We hear again, as we did incessantly from the ...
#
#                                             label_data
# 0                         according to a UN estimate.
# 1     the country would not last long without an ou...
# 2     gets Earl Warren and Sen. Richard Russel to j...
# 3                                                 You
# 4                                            infidels
# ..                                                 ...
# 575                                  Family, Marriage
# 576                       tales start with ‘once I am
# 577                                               not
# 578   He also sang an Islamic State fight song and ...
# 579   with whom, I guess, she has also no choice bu...
#
# [580 rows x 3 columns]

# %%
df_test['multi_label'] = pd.Categorical(df_test['label']).codes
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df_test
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                          label
# 0               not_propaganda  \
# 1    causal_oversimplification
# 2     appeal_to_fear_prejudice
# 3               not_propaganda
# 4                   repetition
# ..                         ...
# 575             not_propaganda
# 576             not_propaganda
# 577             not_propaganda
# 578                flag_waving
# 579  causal_oversimplification
#
#                                      tagged_in_context
# 0    On average, between 300 and 600 infections are...  \
# 1    Mostly because <BOS> the country would not las...
# 2    Lyndon Johnson <BOS> gets Earl Warren and Sen....
# 3             <BOS> You <EOS> may opt out at anytime.
# 4    It must be exacted from him directly in order ...
# ..                                                 ...
# 575  NewsCatholic Church, <BOS> Family, Marriage <E...
# 576  Remember our saying, modern day fairy <BOS> ta...
# 577  Why <BOS> not <EOS> open up to Iran with massi...
# 578  <BOS> He also sang an Islamic State fight song...
# 579  We hear again, as we did incessantly from the ...
#
#                                             label_data  multi_label
# 0                         according to a UN estimate.             7
# 1     the country would not last long without an ou...            1
# 2     gets Earl Warren and Sen. Richard Russel to j...            0
# 3                                                 You             7
# 4                                            infidels             8
# ..                                                 ...          ...
# 575                                  Family, Marriage             7
# 576                       tales start with ‘once I am             7
# 577                                               not             7
# 578   He also sang an Islamic State fight song and ...            4
# 579   with whom, I guess, she has also no choice bu...            1
#
# [580 rows x 4 columns]

# %%
df_train['label']=df_train['label'].apply(lambda x: 1 if x=='not_propaganda' else 0)
df_train.head()
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    label                                  tagged_in_context
# 0      1         No, <BOS> he <EOS> will not be confirmed.   \
# 1      1  This declassification effort <BOS> won’t make ...
# 2      0  The Obama administration misled the <BOS> Amer...
# 3      1  “It looks like we’re capturing the demise of t...
# 4      1           <BOS> Location: Westerville, Ohio <EOS>
#
#                                           label_data  multi_label
# 0                                                he             7
# 1   won’t make things any worse than they are for...            7
# 2                                   American people             4
# 3                                               and             7
# 4                       Location: Westerville, Ohio             7

# %%
df_test['label']=df_test['label'].apply(lambda x: 1 if x=='not_propaganda' else 0)
df_test.head()
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    label                                  tagged_in_context
# 0      1  On average, between 300 and 600 infections are...  \
# 1      0  Mostly because <BOS> the country would not las...
# 2      0  Lyndon Johnson <BOS> gets Earl Warren and Sen....
# 3      1           <BOS> You <EOS> may opt out at anytime.
# 4      0  It must be exacted from him directly in order ...
#
#                                           label_data  multi_label
# 0                       according to a UN estimate.             7
# 1   the country would not last long without an ou...            1
# 2   gets Earl Warren and Sen. Richard Russel to j...            0
# 3                                               You             7
# 4                                          infidels             8

# %%
# target label distribution
df_train.label.plot(kind='hist', title="Target Distribution")
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <Axes: title={'center': 'Target Distribution'}, ylabel='Frequency'>

# %%
df_train1=df_train.loc[df_train['label']==0]
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df_train1.multi_label.plot(kind='hist', title="Target Distribution")
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <Axes: title={'center': 'Target Distribution'}, ylabel='Frequency'>

# %%
df_train.multi_label.plot(kind='hist', title="Target Distribution")
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <Axes: title={'center': 'Target Distribution'}, ylabel='Frequency'>

# %%
df_test.label.plot(kind='hist', title="Target Distribution")
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <Axes: title={'center': 'Target Distribution'}, ylabel='Frequency'>

# %%
df_test.multi_label.plot(kind='hist', title="Target Distribution")
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <Axes: title={'center': 'Target Distribution'}, ylabel='Frequency'>

# %%
df_test1=df_test.loc[df_test['label']==0]
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df_test1
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#      label                                  tagged_in_context
# 1        0  Mostly because <BOS> the country would not las...  \
# 2        0  Lyndon Johnson <BOS> gets Earl Warren and Sen....
# 4        0  It must be exacted from him directly in order ...
# 5        0  Is it any wonder that priests and laity alike ...
# 6        0  Health workers have been asked to work with co...
# ..     ...                                                ...
# 569      0  As a result, 58,177 <BOS> Americans <EOS> woul...
# 571      0  <BOS> But if you are a freedom-loving American...
# 572      0  I heard lots of <BOS> gut-wrenching stories <E...
# 578      0  <BOS> He also sang an Islamic State fight song...
# 579      0  We hear again, as we did incessantly from the ...
#
#                                             label_data  multi_label
# 1     the country would not last long without an ou...            1
# 2     gets Earl Warren and Sen. Richard Russel to j...            0
# 4                                            infidels             8
# 5                                  the "gay lifestyle             6
# 6                             devastating communities             5
# ..                                                 ...          ...
# 569                                         Americans             4
# 571          But if you are a freedom-loving American             4
# 572                             gut-wrenching stories             5
# 578   He also sang an Islamic State fight song and ...            4
# 579   with whom, I guess, she has also no choice bu...            1
#
# [279 rows x 4 columns]

# %%
df_test1.multi_label.plot(kind='hist', title="Target Distribution")
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <Axes: title={'center': 'Target Distribution'}, ylabel='Frequency'>

# %%
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ### Create tf.data.Datasets for Training and Evaluation

# %% [markdown]
# We will be working with only a small portion of data since the data is huge and finetuning the bert model and that big size would considerabely take large amount of time.

# %%
train_df= df_train
val_df, test_df = train_test_split(df_test, random_state=42, train_size = 0.70, stratify = df_test['label'])

print(train_df.shape, val_df.shape)
# Out:
# (2414, 4) (406, 4)
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
test_df
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#      label                                  tagged_in_context
# 486      1  Ed Pentin has a long file of interviews and ar...  \
# 291      1  To <BOS> achieve that and hold onto power the ...
# 2        0  Lyndon Johnson <BOS> gets Earl Warren and Sen....
# 165      0  <BOS> In a nation guided by fairness and law, ...
# 128      0  <BOS> Of course, we know what Obama did with h...
# ..     ...                                                ...
# 205      0  There is no low to which the Democrats will no...
# 207      1  |Patrick <BOS> J. <EOS> Buchanan: Boehner's Ri...
# 373      1       The insults were not <BOS> forgotten. <EOS>
# 213      0  And now <BOS> she has gone full rogue <EOS>, p...
# 186      1           They are <BOS> not <EOS> crimes, right?
#
#                                             label_data  multi_label
# 486   that clearly show his complete inability to m...            7
# 291   achieve that and hold onto power the prime mi...            7
# 2     gets Earl Warren and Sen. Richard Russel to j...            0
# 165   In a nation guided by fairness and law, a per...            4
# 128   Of course, we know what Obama did with his da...            2
# ..                                                 ...          ...
# 205    strengthening America and protecting Americans             4
# 207                                                J.             7
# 373                                        forgotten.             7
# 213                           she has gone full rogue             5
# 186                                               not             7
#
# [174 rows x 4 columns]

# %%
with tf.device('/cpu:0'):
  train_data = tf.data.Dataset.from_tensor_slices((train_df['tagged_in_context'].values, train_df['label'].values))
  val_data = tf.data.Dataset.from_tensor_slices((val_df['tagged_in_context'].values, val_df['label'].values))

  for text, label in train_data.take(1):
    print(text)
    print(label)
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# tf.Tensor(b'No, <BOS> he <EOS> will not be confirmed. ', shape=(), dtype=string)
# tf.Tensor(1, shape=(), dtype=int64)

# %% [markdown]
# ## Pretrainted BERT Model

# %% [markdown]
# ### Download a Pre-trained BERT Model from TensorFlow Hub

# %%
"""
Each line of the dataset is composed of the review text and its label
- Data preprocessing consists of transforming text to BERT input features:
input_word_ids, input_mask, segment_ids
- In the process, tokenizing the text is done with the provided BERT model tokenizer
"""

# Label categories
label_list = [0, 1]

# maximum length of (token) input sequences
max_seq_length = 128  # default max length

train_batch_size = 32
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Get BERT layer and tokenizer
bert_layer = 'https://tfhub.dev/tensorflow/bert_en_uncased_L-12_H-768_A-12/4'
tokenizer = 'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3'
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# create keras layers to preprocess the text and encode to fit to the bert model

text_input = tf.keras.layers.Input(shape=(), dtype=tf.string, name = 'inputs')

# preprocessing
preprocessor = hub.KerasLayer(tokenizer)
encoder_inputs = preprocessor(text_input)

preprocess_model = tf.keras.Model(text_input, encoder_inputs)
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ### Create a TensorFlow Input Pipeline with `tf.data`

# %%
with tf.device('/cpu:0'):
  # train
  train_data = train_data.shuffle(1000).batch(32, drop_remainder = True).prefetch(tf.data.experimental.AUTOTUNE)

  # valid
  val_data = val_data.batch(32, drop_remainder = True).prefetch(tf.data.experimental.AUTOTUNE)
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# train data spec
train_data.element_spec
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (TensorSpec(shape=(32,), dtype=tf.string, name=None),
#  TensorSpec(shape=(32,), dtype=tf.int64, name=None))

# %%
# valid data spec
val_data.element_spec
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (TensorSpec(shape=(32,), dtype=tf.string, name=None),
#  TensorSpec(shape=(32,), dtype=tf.int64, name=None))

# %%
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ## First Task Model #1

# %% [markdown]
# Build and evaluate at least 2 approaches to classify whether a sentence contains propaganda or not.

# %% [markdown]
# ### Add a Classification Head to the BERT Layer

# %%
# Building the model
def create_model():
  
  text_input = tf.keras.layers.Input(shape=(), dtype=tf.string, name = 'inputs')

  # preprocessing
  preprocessor = hub.KerasLayer(tokenizer)
  encoder_inputs = preprocessor(text_input)

  # passing the encoded inputs to bert model
  encoder = hub.KerasLayer(bert_layer, trainable=True, name = 'BERT_Encoder')
  outputs = encoder(encoder_inputs)

  # get the pooled outputs
  pooled_output = outputs['pooled_output']

  # add output layer
  batch_norm = tf.keras.layers.BatchNormalization()(pooled_output)
  drop = tf.keras.layers.Dropout(0.4)(batch_norm)
  fc = tf.keras.layers.Dense(128, activation='relu')(drop)
  final_output = tf.keras.layers.Dense(1, activation='sigmoid', name='classifier')(fc)
    
  return tf.keras.Model(text_input, final_output)
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ### Fine-Tune BERT for Text Classification

# %%
model = create_model()
model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate=2e-5), 
              loss = tf.keras.losses.BinaryCrossentropy(),
              metrics = [tf.keras.metrics.BinaryAccuracy()])
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  inputs (InputLayer)            [(None,)]            0           []
#
#  keras_layer_1 (KerasLayer)     {'input_word_ids':   0           ['inputs[0][0]']
#                                 (None, 128),
#                                  'input_mask': (Non
#                                 e, 128),
#                                  'input_type_ids':
#                                 (None, 128)}
#
#  BERT_Encoder (KerasLayer)      {'default': (None,   109482241   ['keras_layer_1[0][0]',
#                                 768),                             'keras_layer_1[0][1]',
#                                  'pooled_output': (               'keras_layer_1[0][2]']
#                                 None, 768),
#                                  'encoder_outputs':
#                                  [(None, 128, 768),
#                                  (None, 128, 768),
#                                  (None, 128, 768),
#                                  (None, 128, 768),
#                                  (None, 128, 768),
#                                  (None, 128, 768),
#                                  (None, 128, 768),
#                                  (None, 128, 768),
#                                  (None, 128, 768),
#                                  (None, 128, 768),
#                                  (None, 128, 768),
#                                  (None, 128, 768)],
#                                  'sequence_output':
#                                  (None, 128, 768)}
#
#  batch_normalization (BatchNorm  (None, 768)         3072        ['BERT_Encoder[0][13]']
#  alization)
#
#  dropout (Dropout)              (None, 768)          0           ['batch_normalization[0][0]']
#
#  dense (Dense)                  (None, 128)          98432       ['dropout[0][0]']
#
#  classifier (Dense)             (None, 1)            129         ['dense[0][0]']
#
# ==================================================================================================
# Total params: 109,583,874
# Trainable params: 109,582,337
# Non-trainable params: 1,537
# __________________________________________________________________________________________________
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Train model
epochs = 4
history = model.fit(train_data, 
                    validation_data=val_data,
                    epochs=epochs, 
                    verbose=1)
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Epoch 1/4
# 75/75 [==============================] - 127s 970ms/step - loss: 0.6128 - binary_accuracy: 0.6875 - val_loss: 0.4651 - val_binary_accuracy: 0.8438
# Epoch 2/4
# 75/75 [==============================] - 71s 946ms/step - loss: 0.2474 - binary_accuracy: 0.9013 - val_loss: 0.3183 - val_binary_accuracy: 0.8698
# Epoch 3/4
# 75/75 [==============================] - 71s 941ms/step - loss: 0.1437 - binary_accuracy: 0.9471 - val_loss: 0.4675 - val_binary_accuracy: 0.8021
# Epoch 4/4
# 75/75 [==============================] - 70s 940ms/step - loss: 0.0803 - binary_accuracy: 0.9704 - val_loss: 0.1964 - val_binary_accuracy: 0.9245

# %% [markdown]
# ### *Evaluate* the BERT Text Classification Model

# %%
import matplotlib.pyplot as plt

def plot_graphs(history, metric):
  plt.plot(history.history[metric])
  plt.plot(history.history['val_'+metric], '')
  plt.xlabel("Epochs")
  plt.ylabel(metric)
  plt.legend([metric, 'val_'+metric])
  plt.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
plot_graphs(history=history, metric='loss')
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
plot_graphs(history,'binary_accuracy')
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# testing on some samples
sample_example = ["We’ll stop <BOS> it,” <EOS> Strzok responded."]
model.predict(sample_example)
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 1/1 [==============================] - 1s 827ms/step
# array([[0.9905475]], dtype=float32)

# %%
sample_example = ["Trump To Jeff Sessions: Put An End to Russia Probe - <BOS> Prosecutors Doing Mueller’s ‘Dirty Work Are A Disgrace’ To America <EOS>"]
model.predict(sample_example)
# Out:
# 1/1 [==============================] - 0s 42ms/step
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# array([[0.00694892]], dtype=float32)

# %%
test=test_df.tagged_in_context
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
prediction=model.predict(test)
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 6/6 [==============================] - 3s 362ms/step

# %%
test_label=test_df.label
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
pred=[1 if i>0.5 else 0 for i in prediction]
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
from sklearn.metrics import classification_report

print(classification_report(test_label, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.98      0.94        84
#            1       0.98      0.91      0.94        90
#
#     accuracy                           0.94       174
#    macro avg       0.94      0.94      0.94       174
# weighted avg       0.94      0.94      0.94       174
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(test_label, pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ## Second Task Model #1

# %% [markdown]
# Given a snippet or span of text which is known to contain propaganda, build and evaluate at least
# 2 approaches to classifying the propaganda technique which has been used.

# %%
train_df1=train_df.loc[train_df['label']==0]
train_df1
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#       label                                  tagged_in_context
# 2         0  The Obama administration misled the <BOS> Amer...  \
# 5         0  Hitler <BOS> annihilated <EOS> 400,000 Germans...
# 8         0  As noted above, at this point literally every ...
# 10        0  His account was suspended for violating Twitte...
# 12        0  A couple of seemingly unrelated events this pa...
# ...     ...                                                ...
# 2403      0  You might think that would have cured him of f...
# 2405      0  “I would like to take this opportunity to make...
# 2406      0  Trump To Jeff Sessions: Put An End to Russia P...
# 2407      0  <BOS> Neither the Democrat leadership nor the ...
# 2413      0  In it, Jews are described as: “arrogant,” “jea...
#
#                                              label_data  multi_label
# 2                                      American people             4
# 5                                          annihilated             5
# 8                                   so-called evidence             2
# 10                                     hateful conduct             6
# 12     point to Iran’s positioning itself for more a...            0
# ...                                                 ...          ...
# 2403                                              Nazi             8
# 2405             absolutely no place for anti-Semitism             3
# 2406   Prosecutors Doing Mueller’s ‘Dirty Work Are A...            4
# 2407   Neither the Democrat leadership nor the Democ...            1
# 2413                                           selfish             6
#
# [1223 rows x 4 columns]

# %%
val_df1 =val_df.loc[val_df['label']==0]
val_df1
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#      label                                  tagged_in_context
# 335      0  In analyzing the highly anticipated OIG report...  \
# 356      0  JStreetPAC, the arm of the NGO that funds and ...
# 345      0  This is starting to look more and more like <B...
# 232      0  REMNANT COMMENT: While we certainly appreciate...
# 77       0  <BOS> The American people are not going to put...
# ..     ...                                                ...
# 9        0  <BOS> Now, the pope’s reply to my testimony wa...
# 542      0  <BOS> Similarly, the Guardian worked tirelessl...
# 492      0  On both of their blogs the pair called their b...
# 1        0  Mostly because <BOS> the country would not las...
# 543      0  <BOS> It’s the very reason the governments of ...
#
#                                             label_data  multi_label
# 335    emerged in a disappointingly watered-down form             2
# 356                           virulently anti-Semitic             5
# 345      a gun running operation gone wrong every day             8
# 232                                  horrific scandal             5
# 77    The American people are not going to put up w...            4
# ..                                                 ...          ...
# 9     Now, the pope’s reply to my testimony was: “I...            2
# 542   Similarly, the Guardian worked tirelessly to ...            2
# 492                   a striking blow against freedom             5
# 1     the country would not last long without an ou...            1
# 543   It’s the very reason the governments of the w...            1
#
# [195 rows x 4 columns]

# %%
with tf.device('/cpu:0'):
  train_data = tf.data.Dataset.from_tensor_slices((train_df1['tagged_in_context'].values, train_df1['multi_label'].values))
  val_data = tf.data.Dataset.from_tensor_slices((val_df1['tagged_in_context'].values, val_df1['multi_label'].values))

  for text, label in train_data.take(1):
    print(text)
    print(label)
# Out:
# tf.Tensor(b'The Obama administration misled the <BOS> American people <EOS> and Congress because they were desperate to get a deal with Iran, said Sen. ', shape=(), dtype=string)
# tf.Tensor(4, shape=(), dtype=int8)
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Label categories
label_list = [0,1,2,3,4,5,6,8]

# maximum length of (token) input sequences
max_seq_length = 128  # default max length

train_batch_size = 32
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
text_input = tf.keras.layers.Input(shape=(), dtype=tf.string, name = 'inputs')

# preprocessing
preprocessor = hub.KerasLayer(tokenizer)
encoder_inputs = preprocessor(text_input)

preprocess_model = tf.keras.Model(text_input, encoder_inputs)
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
with tf.device('/cpu:0'):
  # train
  train_data = train_data.shuffle(1000).batch(32, drop_remainder = True).prefetch(tf.data.experimental.AUTOTUNE)

  # valid
  val_data = val_data.batch(32, drop_remainder = True).prefetch(tf.data.experimental.AUTOTUNE)
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
def create_model():
  
  text_input = tf.keras.layers.Input(shape=(), dtype=tf.string, name = 'inputs')

  # preprocessing
  preprocessor = hub.KerasLayer(tokenizer)
  encoder_inputs = preprocessor(text_input)

  # passing the encoded inputs to bert model
  encoder = hub.KerasLayer(bert_layer, trainable=True, name = 'BERT_Encoder')
  outputs = encoder(encoder_inputs)

  # get the pooled outputs
  pooled_output = outputs['pooled_output']

  # add output layer and because it is multiclassification so we need to get 9 possible outcomes. 
  batch_norm = tf.keras.layers.BatchNormalization()(pooled_output)
  drop = tf.keras.layers.Dropout(0.4)(batch_norm)
  fc = tf.keras.layers.Dense(128, activation='relu')(drop)
  final_output = tf.keras.layers.Dense(9, activation='softmax', name='classifier')(fc)
    
  return tf.keras.Model(text_input, final_output)
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# for loss we used sparse_categorical_crossentropy because of multiclassification.
model = create_model()
model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate=2e-5), 
              loss = 'sparse_categorical_crossentropy',
              metrics = 'accuracy')
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Train model    
epochs = 8
history = model.fit(train_data, 
                    validation_data=val_data,
                    epochs=epochs, 
                    verbose=1)
# Out:
# Epoch 1/8
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 38/38 [==============================] - 88s 975ms/step - loss: 2.7536 - accuracy: 0.1505 - val_loss: 2.4678 - val_accuracy: 0.1250
# Epoch 2/8
# 38/38 [==============================] - 36s 944ms/step - loss: 2.2179 - accuracy: 0.2294 - val_loss: 2.4456 - val_accuracy: 0.1250
# Epoch 3/8
# 38/38 [==============================] - 36s 941ms/step - loss: 1.8790 - accuracy: 0.3314 - val_loss: 2.2608 - val_accuracy: 0.1250
# Epoch 4/8
# 38/38 [==============================] - 36s 945ms/step - loss: 1.6619 - accuracy: 0.4104 - val_loss: 2.1102 - val_accuracy: 0.1510
# Epoch 5/8
# 38/38 [==============================] - 36s 941ms/step - loss: 1.4060 - accuracy: 0.4951 - val_loss: 1.9391 - val_accuracy: 0.2969
# Epoch 6/8
# 38/38 [==============================] - 36s 944ms/step - loss: 1.1422 - accuracy: 0.5929 - val_loss: 1.6394 - val_accuracy: 0.4740
# Epoch 7/8
# 38/38 [==============================] - 36s 938ms/step - loss: 0.8912 - accuracy: 0.7105 - val_loss: 1.4304 - val_accuracy: 0.4688
# Epoch 8/8
# 38/38 [==============================] - 36s 939ms/step - loss: 0.6748 - accuracy: 0.7574 - val_loss: 1.3761 - val_accuracy: 0.4844

# %%
def plot_graphs(history, metric):
  plt.plot(history.history[metric])
  plt.plot(history.history['val_'+metric], '')
  plt.xlabel("Epochs")
  plt.ylabel(metric)
  plt.legend([metric, 'val_'+metric])
  plt.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
plot_graphs(history=history, metric='loss')
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
plot_graphs(history,'accuracy')
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
test_df1=test_df.loc[test_df.label==0]
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
test_df1
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#      label                                  tagged_in_context
# 2        0  Lyndon Johnson <BOS> gets Earl Warren and Sen....  \
# 165      0  <BOS> In a nation guided by fairness and law, ...
# 128      0  <BOS> Of course, we know what Obama did with h...
# 347      0  As every false accusation has fallen away, eve...
# 95       0  <BOS> The enemy is not only at the gates but h...
# ..     ...                                                ...
# 318      0  In a subsequent Facebook post, Lew wrote, “<BO...
# 127      0  <BOS> I respectfully suggest that Dr. Fastiggi...
# 480      0  With the ease of spreading the plague, <BOS> t...
# 205      0  There is no low to which the Democrats will no...
# 213      0  And now <BOS> she has gone full rogue <EOS>, p...
#
#                                             label_data  multi_label
# 2     gets Earl Warren and Sen. Richard Russel to j...            0
# 165   In a nation guided by fairness and law, a per...            4
# 128   Of course, we know what Obama did with his da...            2
# 347   one who has exposed a system that threatens h...            3
# 95    The enemy is not only at the gates but has no...            0
# ..                                                 ...          ...
# 318   My Jewish identity was now public, and a targ...            1
# 127   I respectfully suggest that Dr. Fastiggi’s co...            2
# 480   the likelihood that this disease will move to...            0
# 205    strengthening America and protecting Americans             4
# 213                           she has gone full rogue             5
#
# [84 rows x 4 columns]

# %%
test=test_df1['tagged_in_context']
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
test
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 2      Lyndon Johnson <BOS> gets Earl Warren and Sen....
# 165    <BOS> In a nation guided by fairness and law, ...
# 128    <BOS> Of course, we know what Obama did with h...
# 347    As every false accusation has fallen away, eve...
# 95     <BOS> The enemy is not only at the gates but h...
#                              ...
# 318    In a subsequent Facebook post, Lew wrote, “<BO...
# 127    <BOS> I respectfully suggest that Dr. Fastiggi...
# 480    With the ease of spreading the plague, <BOS> t...
# 205    There is no low to which the Democrats will no...
# 213    And now <BOS> she has gone full rogue <EOS>, p...
# Name: tagged_in_context, Length: 84, dtype: object

# %%
test_label=test_df1.multi_label
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
test_label
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 2      0
# 165    4
# 128    2
# 347    3
# 95     0
#       ..
# 318    1
# 127    2
# 480    0
# 205    4
# 213    5
# Name: multi_label, Length: 84, dtype: int8

# %%
prediction=model.predict(test)
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 3/3 [==============================] - 1s 319ms/step

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix

def plot_cm(model, test_data, test_labels):
    
    products = ['appeal_to_fear_prejudice','causal_oversimplification','doubt','exaggeration','flag_waving','loaded_language','name_calling', 'repetition']
        
    # Calculate predictions
    pred = model.predict(test_data)
    
    # Declaring confusion matrix
    cm = confusion_matrix(test_labels, np.argmax(pred, axis=1))
    
    # Heat map labels

    group_counts = ['{0:0.0f}'.format(value) for value in cm.flatten()]
    group_percentages = ['{0:.1%}'.format(value) for value in cm.flatten()/np.sum(cm)]
    
    labels = [f"{v2}\n{v3}" for v2, v3 in zip(group_counts, group_percentages)]
    labels = np.asarray(labels).reshape(8,8)

    # Plotting confusion matrix
    plt.figure(figsize=(12,8))
    
    sns.heatmap(cm, cmap=plt.cm.Blues, annot=labels, annot_kws={"size": 15}, fmt = '',
                xticklabels = products,
                yticklabels = products)
    
    plt.xticks(fontsize = 12)
    plt.yticks(fontsize = 12, rotation = 'horizontal')
    plt.title('Confusion Matrix\n', fontsize=19)
    plt.xlabel('Predicted Labels', fontsize=17)
    plt.ylabel('Actual Labels', fontsize=17)
    
plot_cm(model, test,test_label)
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 3/3 [==============================] - 1s 310ms/step

# %%
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ## First Task Model #2

# %% [markdown]
# Build and evaluate at least 2 approaches to classify whether a sentence contains propaganda or not

# %% [markdown]
# ## Second Model BiLSTM

# %%
#Make a vocab size for the training dataset.
vocab_size = 5000
oov_tok = "<OOV>"
tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(np.array(train_df.tagged_in_context))
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#In this function first create text to sequence then add padding into into to make equal size of input size.
sequence_length=30
def word_to_vector(text):
    return pad_sequences(tokenizer.texts_to_sequences(text), maxlen=sequence_length, padding='post', truncating='post')
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
train_padded=word_to_vector(np.array(train_df.tagged_in_context))
test_padded=word_to_vector(np.array(df_test.tagged_in_context))
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
y_train=train_df.label
y_test=df_test.label
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
model = Sequential()
embedding_dim = 16
model.add(Embedding(vocab_size, embedding_dim, input_length=sequence_length))
lstm_out = 64
model.add(Bidirectional(LSTM(lstm_out)))
model.add(Dense(32, kernel_regularizer=regularizers.l2(0.01)))
model.add(Dropout(0.25))
model.add(Dense(16, kernel_regularizer=regularizers.l2(0.01)))
model.add(Dropout(0.25))
model.add(Dense(8, activation='relu'))

model.add(Dense(1, activation='sigmoid'))
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 30, 16)            80000
#
#  bidirectional (Bidirectiona  (None, 128)              41472
#  l)
#
#  dense_2 (Dense)             (None, 32)                4128
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense_3 (Dense)             (None, 16)                528
#
#  dropout_3 (Dropout)         (None, 16)                0
#
#  dense_4 (Dense)             (None, 8)                 136
#
#  dense_5 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 126,273
# Trainable params: 126,273
# Non-trainable params: 0
# _________________________________________________________________
# None
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
import os
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
checkpoint_filepath = os.getcwd()
model_checkpoint_callback = ModelCheckpoint(filepath=checkpoint_filepath, save_weights_only=False, monitor='val_loss', mode='min', save_best_only=True)
callbacks = [EarlyStopping(patience=3), model_checkpoint_callback]
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
history = model.fit(train_padded, y_train, epochs=5, validation_data=(test_padded, y_test), callbacks=callbacks)
# Out:
# Epoch 1/5
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 76/76 [==============================] - ETA: 0s - loss: 1.1386 - accuracy: 0.5829
# WARNING:absl:Found untraced functions such as lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# 76/76 [==============================] - 38s 389ms/step - loss: 1.1386 - accuracy: 0.5829 - val_loss: 0.9202 - val_accuracy: 0.6431
# Epoch 2/5
# 76/76 [==============================] - ETA: 0s - loss: 0.7367 - accuracy: 0.7237
# WARNING:absl:Found untraced functions such as lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# 76/76 [==============================] - 19s 250ms/step - loss: 0.7367 - accuracy: 0.7237 - val_loss: 0.7024 - val_accuracy: 0.6966
# Epoch 3/5
# 76/76 [==============================] - 5s 60ms/step - loss: 0.4585 - accuracy: 0.8641 - val_loss: 0.7494 - val_accuracy: 0.6741
# Epoch 4/5
# 76/76 [==============================] - 4s 46ms/step - loss: 0.2961 - accuracy: 0.9163 - val_loss: 0.8035 - val_accuracy: 0.6862
# Epoch 5/5
# 76/76 [==============================] - 2s 25ms/step - loss: 0.1874 - accuracy: 0.9582 - val_loss: 0.8122 - val_accuracy: 0.6793

# %%
metrics_df = pd.DataFrame(history.history)
print(metrics_df)
# Out:
#        loss  accuracy  val_loss  val_accuracy
# 0  1.138606  0.582850  0.920172      0.643103
# 1  0.736666  0.723695  0.702403      0.696552
# 2  0.458521  0.864126  0.749363      0.674138
# 3  0.296080  0.916321  0.803499      0.686207
# 4  0.187366  0.958161  0.812164      0.679310
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
plt.figure(figsize=(10,5))
plt.plot(metrics_df.index, metrics_df.loss)
plt.plot(metrics_df.index, metrics_df.val_loss)
plt.title('Propaganda Analysis Model Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Binary Crossentropy')
plt.legend(['Training Loss', 'Validation Loss'])
plt.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
plt.figure(figsize=(10,5))
plt.plot(metrics_df.index, metrics_df.accuracy)
plt.plot(metrics_df.index, metrics_df.val_accuracy)
plt.title('Propaganda Analysis Model Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Training Accuracy', 'Validation Accuracy'])
plt.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
test_model=word_to_vector(test_df.tagged_in_context)
test_labels=test_df.label
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
from sklearn.metrics import confusion_matrix
predic=model.predict(test_model)
res=[]
for i in predic:
    if i>0.5:
        res.append(1)
    else:
        res.append(0)
result = confusion_matrix(test_labels, res)
print(result)
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 6/6 [==============================] - 1s 4ms/step
# [[64 20]
#  [33 57]]

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(test_labels, res)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ## Second Task Model #2

# %% [markdown]
# Given a snippet or span of text which is known to contain propaganda, build and evaluate at least
# 2 approaches to classifying the propaganda technique which has been used

# %%
model = Sequential()
embedding_dim = 16
model.add(Embedding(vocab_size, embedding_dim, input_length=sequence_length))
lstm_out = 64
model.add(Bidirectional(LSTM(lstm_out)))
model.add(Dense(32, kernel_regularizer=regularizers.l2(0.01)))
model.add(Dropout(0.25))
model.add(Dense(16, kernel_regularizer=regularizers.l2(0.01)))
model.add(Dropout(0.25))

model.add(Dense(9, activation='softmax'))
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
train_padded=word_to_vector(np.array(train_df1['tagged_in_context']))
test_padded=word_to_vector(np.array(df_test1['tagged_in_context']))
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
y_train=train_df1.multi_label
y_test=df_test1.multi_label
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
y_test
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 1      1
# 2      0
# 4      8
# 5      6
# 6      5
#       ..
# 569    4
# 571    4
# 572    5
# 578    4
# 579    1
# Name: multi_label, Length: 279, dtype: int8

# %%
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
history = model.fit(train_padded,y_train, epochs=8, validation_data=(test_padded, y_test), callbacks=callbacks)
# Out:
# Epoch 1/8
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 39/39 [==============================] - 12s 139ms/step - loss: 2.7472 - accuracy: 0.1357 - val_loss: 2.5685 - val_accuracy: 0.1326
# Epoch 2/8
# 39/39 [==============================] - 6s 150ms/step - loss: 2.5250 - accuracy: 0.1276 - val_loss: 2.4333 - val_accuracy: 0.1864
# Epoch 3/8
# 39/39 [==============================] - 7s 166ms/step - loss: 2.3896 - accuracy: 0.1423 - val_loss: 2.3302 - val_accuracy: 0.1685
# Epoch 4/8
# 39/39 [==============================] - 5s 107ms/step - loss: 2.2695 - accuracy: 0.1643 - val_loss: 2.2190 - val_accuracy: 0.1828
# Epoch 5/8
# 39/39 [==============================] - 2s 55ms/step - loss: 2.0694 - accuracy: 0.2551 - val_loss: 2.2789 - val_accuracy: 0.2115
# Epoch 6/8
# 39/39 [==============================] - 2s 44ms/step - loss: 1.8549 - accuracy: 0.3393 - val_loss: 2.1880 - val_accuracy: 0.2258
# Epoch 7/8
# 39/39 [==============================] - 1s 19ms/step - loss: 1.6642 - accuracy: 0.4235 - val_loss: 2.3501 - val_accuracy: 0.2401
# Epoch 8/8
# 39/39 [==============================] - 1s 26ms/step - loss: 1.4753 - accuracy: 0.4710 - val_loss: 2.3371 - val_accuracy: 0.2437

# %%
metrics_df = pd.DataFrame(history.history)
print(metrics_df)
# Out:
#        loss  accuracy  val_loss  val_accuracy
# 0  2.747249  0.135732  2.568494      0.132616
# 1  2.525017  0.127555  2.433331      0.186380
# 2  2.389617  0.142273  2.330246      0.168459
# 3  2.269451  0.164350  2.219018      0.182796
# 4  2.069406  0.255110  2.278924      0.211470
# 5  1.854858  0.339330  2.188037      0.225806
# 6  1.664202  0.423549  2.350135      0.240143
# 7  1.475345  0.470973  2.337062      0.243728
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
plt.figure(figsize=(10,5))
plt.plot(metrics_df.index, metrics_df.loss)
plt.plot(metrics_df.index, metrics_df.val_loss)
plt.title('Propaganda Analysis Model Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('sparse_categorical_crossentropy')
plt.legend(['Training Loss', 'Validation Loss'])
plt.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
plt.figure(figsize=(10,5))
plt.plot(metrics_df.index, metrics_df.accuracy)
plt.plot(metrics_df.index, metrics_df.val_accuracy)
plt.title('Propaganda Analysis Model Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Training Accuracy', 'Validation Accuracy'])
plt.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
test_model=word_to_vector(test_df1['tagged_in_context'])
test_labels=test_df1.multi_label
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
plot_cm(model, test_model,test_labels)
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 3/3 [==============================] - 1s 6ms/step
